# %% [markdown]
# <a href="https://colab.research.google.com/github/YanuarRamadhaniKuswoko/Pembelajaran_Mesin_2026/blob/main/ti_244107020172_yanuar_ramadhani_k_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tugas Praktikum 1**

# %% [markdown]
# 1.Buat file notebook dengan nama T1_NIM_NAMA.ipynb . Contoh:
# T1_244107020172_Yanuar.ipynb .

# %%
# !pip install mne

# %% [markdown]
# TUGAS PRAKTIKUM

# %% [markdown]
# 2.Lakukan instalasi library berikut pada notebook,
# a. PyPREP
# b. Scipy
# c. wandb
# d. pyECG

# %%
# !pip install PyPREP
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install Scipy

# %%
# !pip install wandb

# %%
# !pip install pyecg --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# 3.Jelaskan kegunakan masing-masing library tersebut.
#
# jawab:
#
# a. PyPREP:untuk pemrosesan sinyal Elektroensefalogram (EEG) secara otomatis dan PyREP ini menerapkan alus kkerja prepocessing Pipeline (PREP) untuk memberikan noise, mendeteksi saluran atau channel rusak,dan referencing ulang pada sinyal otak
#
# b. Scipy:Library standar phyton untuk komputasi ilmiah dan teknis dan juga menyediakan modul aljabar linier,optimasi,integrasi numerik,pemrosesan sinyal,hingga statistik dasar maupun akhir
#
#
# c. wandb:platform untuk membantu,melacak,dan menvisualisasikan eksperimen Mchile Learning ataupun Deep Learning.Digunakan untuk mencatat hyperparameter,matriks performa model,serta hasil uji antar eksperimen secara real time
#
#
# d. pyECG:untuk memproses dan menganalisis sinyal Elektrokardiogram(EEG/EKG).Library ini digunakan untuk membantu ekstrasi fitur sinyal jantungseperti deteksi gelombang R(R-peak detection),analisis variabilitas detak jantung (HRV) dan pra-pemrosesan sinyal detak jantung

# %% [markdown]
# **Bagian 2**

# %% [markdown]
# 1.Berikan contoh tentang tidakan melanggar etika dan hukum tentang
# penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# jawab:Contoh Kasus: Penyalahgunaan Deepfake untuk Pencemaran Nama Baik dan Penipuan
# Penggunaan teknologi generatif AI untuk membuat video, suara, atau gambar palsu yang sangat mirip dengan aslinya (deepfake) tanpa izin merupakan bentuk pelanggaran etika dan hukum.
#
# Pelanggaran Etika: Merekam atau merkayasa privasi, identitas, serta citra diri seseorang tanpa persetujuan (consent), yang merusak reputasi dan memanipulasi kebenaran publik.
#
# Pelanggaran Hukum: Di Indonesia, tindakan ini melanggar Pasal 27A dan Pasal 28 ayat (1) UU ITE (UU No. 1 Tahun 2024) terkait pencemaran nama baik dan penyebaran berita bohong yang merugikan, serta ketentuan perlindungan data pribadi dalam UU No. 27 Tahun 2022 (UU PDP). Kasus nyata yang sering terjadi adalah penipuan berbasis voice cloning untuk meminta uang kepada keluarga korban.
#
# referensi:https://peraturan.bpk.go.id/Details/274494/uu-no-1-tahun-2024.

# %% [markdown]
# 2.Berikan contoh tentang dampak energi dan lingkungan terhadap
# pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya
# (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang
# digunakan.
#
# jawab:Konsumsi Energi: Proses pelatihan satu model AI skala besar dapat mengonsumsi energi listrik setara dengan kebutuhan ratusan rumah tangga selama setahun.
#
# Menurut pandangan saya, pengembangan AI tidak boleh mengorbankan keberlanjutan lingkungan. Solusi yang dapat diterapkan meliputi:
# -Efisiensi Algoritma (Green AI): Mengembangkan teknik kompresi model (seperti quantization dan pruning) agar AI dapat berjalan dengan konsumsi daya yang lebih rendah tanpa menurunkan performa secara signifikan.
#
# -Transisi Energi Terbarukan: Perusahaan penyedia data center wajib mengalihkan sumber energinya ke energi terbarukan (surya, angin, atau hidro).
#
# referensi:https://www.iea.org/reports/electricity-2024
